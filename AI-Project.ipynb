# %% [markdown]
# <a href="https://colab.research.google.com/github/aastha621/Artificial-Intelligence/blob/main/AI-Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import io
from google.colab import drive
# uploaded = files.upload()

# df = pd.read_csv(io.BytesIO(uploaded['ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train.csv'])) 

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = "/content/drive/MyDrive/kaggle"

# %%
# !kaggle competitions download -c multilingualabusivecomment
# Out:
# ...
#   0% 0.00/4.82M [00:00<?, ?B/s]
# 100% 4.82M/4.82M [00:00<00:00, 75.4MB/s]
# ...
#  82% 41.0M/50.0M [00:00<00:00, 116MB/s]
# 100% 50.0M/50.0M [00:00<00:00, 126MB/s]

# %%
# !ls
# Out:
#  drive
#  sample_data
#  ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Test_20_Percent_NoLabel.csv.zip
# 'ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train (1).csv'
#  ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train.csv
#  ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train.csv.zip

# %%
# !unzip \*.zip  && rm *.zip
# Out:
# Archive:  ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Test_20_Percent_NoLabel.csv.zip
#   inflating: ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Test_20_Percent_NoLabel.csv
#
# Archive:  ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train.csv.zip
# replace ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train.csv
#
# 2 archives were successfully processed.

# %%
df=pd.read_csv('ShareChat-IndoML-Datathon-NSFW-CommentChallenge_Train.csv',error_bad_lines=False)
# Out:
# b'Skipping line 446: expected 10 fields, saw 13\nSkipping line 614: expected 10 fields, saw 11\nSkipping line 2576: expected 10 fields, saw 13\nSkipping line 2762: expected 10 fields, saw 18\nSkipping line 3384: expected 10 fields, saw 11\nSkipping line 3831: expected 10 fields, saw 11\nSkipping line 3892: expected 10 fields, saw 12\nSkipping line 4037: expected 10 fields, saw 11\nSkipping line 4042: expected 10 fields, saw 12\nSkipping line 4739: expected 10 fields, saw 16\nSkipping line 4846: expected 10 fields, saw 11\nSkipping line 5306: expected 10 fields, saw 11\nSkipping line 6271: expected 10 fields, saw 16\nSkipping line 7853: expected 10 fields, saw 11\nSkipping line 8970: expected 10 fields, saw 11\nSkipping line 9937: expected 10 fields, saw 16\nSkipping line 10511: expected 10 fields, saw 13\nSkipping line 11199: expected 10 fields, saw 11\nSkipping line 11455: expected 10 fields, saw 11\nSkipping line 11711: expected 10 fields, saw 11\nSkipping line 11785: expected 10 f
# ...

# %%
df.head(20)
# Out:
#     CommentId  ... label
# 0           0  ...   1.0
# 1           1  ...   0.0
# 2           2  ...   1.0
# 3           3  ...   0.0
# 4           4  ...   1.0
# 5           5  ...   0.0
# 6           6  ...   0.0
# 7           7  ...   0.0
# 8           8  ...   0.0
# 9           9  ...   1.0
# 10         10  ...   0.0
# 11         11  ...   1.0
# 12         12  ...   0.0
# 13         13  ...   1.0
# 14         14  ...   0.0
# 15         15  ...   0.0
# 16         16  ...   1.0
# 17         17  ...   0.0
# 18         18  ...   1.0
# 19         19  ...   0.0
#
# [20 rows x 10 columns]

# %%
df['language'].value_counts()
# Out:
# Hindi                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 
# ...

# %%
# Using regex
import re

# %%
df.dropna(inplace=True)

# %%
for i in range(len(df)) :
  res = bool(re.search(r"\s", df.iloc[i,2]))
  if  res:
    df.drop(df.iloc[i],inplace=true)

# %%
df
# Out:
#          CommentId                                        commentText  \
# 0                0                                   randi ka deewana
# 1                1                                         👌👌🙏🥰🥰🥰☝️☝️
# 2                2  apni pant utar kar apni chut bhi to bata do ma...
# 3                3  krishnatripathi4578 jesi ghar ki sabhyata vais...
# 4                4   is randi ko dusra kaam nahi hai kuttiya kahin ki
# ...            ...                                                ...
# 1483501    1500893                                       pavam🤣 😁😻😻😻😻
# 1483502    1500894                          enik ind post ittittila 😔
# 1483503    1500895                                nirmelp34 parayilla
# 1483504    1500896                                            ettan🙈😘
# 1483505    1500897                                              👌👏😄😄😜
#
#            language user_index post_index report_count_comment  \
# ...

# %%
language=df['language'].value_counts()
print(language)
# Out:
# Hindi         493264
# English       173508
# Malayalam     160954
# Telugu        145620
# Tamil         126560
# Punjabi       101894
# Kannada        80749
# Bengali        46507
# Odia           37650
# Bhojpuri       37545
# Marathi        30673
# Gujarati       23405
# Haryanvi       13048
# Rajasthani      5159
# Assamese        3564
# Urdu            3186
# Name: language, dtype: int64

# %%
language= np.array(language)
unlang = df.language.unique()
print(unlang)
print(language)
# Out:
# ['Assamese' 'Rajasthani' 'Urdu' 'Odia' 'Hindi' 'Telugu' 'Bengali'
#  'English' 'Kannada' 'Marathi' 'Punjabi' 'Bhojpuri' 'Gujarati' 'Haryanvi'
#  'Malayalam' 'Tamil']
# [493264 173508 160954 145620 126560 101894  80749  46507  37650  37545
#   30673  23405  13048   5159   3564   3186]

# %%
import numpy as np

# %%
from pandas import Series
# ser = pd.Series(data=d, index=['a', 'b', 'c'])
unlang=['Hindi','English','Malayalam','Telugu','Tamil','Punjabi','Kannada' ,'Bengali' ,'Odia','Bhojpuri','Marathi', 'Gujarati','Haryanvi','Rajasthani','Assamese','Urdu']

# %%
language
print(unlang)
# Out:
# ['Hindi', 'English', 'Malayalam', 'Telugu', 'Tamil', 'Punjabi', 'Kannada', 'Bengali', 'Odia', 'Bhojpuri', 'Marathi', 'Gujarati', 'Haryanvi', 'Rajasthani', 'Assamese', 'Urdu']

# %%
from matplotlib import pyplot as plt
import numpy as np
  
  

fig = plt.figure(figsize =(10, 7))
# plt.pie(language, labels=unlang)
patches, texts = plt.pie(language, startangle=90)
plt.legend(patches, unlang, loc="upper center", bbox_to_anchor=(1.05, 1))
plt.title('Distribution of Languages used in comments')
plt.tight_layout()
  
# show plot
plt.show()

# %%
x = unlang
y = language

plt.barh(x,y)
plt.title('Distribution of Languages used in comments')
plt.show()

# %%
ab=df['label'].value_counts()
print(ab)
ab=np.array(ab)
# Out:
# 0.0    1135896
# 1.0     347390
# Name: label, dtype: int64

# %%
fig = plt.figure(figsize =(10, 7))
# plt.pie(language, labels=unlang)
label=['Non Abusive', 'Abusive']
patches, texts = plt.pie(ab, startangle=90)
plt.legend(patches, label , loc="upper center", bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.title('Types of Comments')
  
# show plot
plt.show()

# %%
y = ab
x = label

plt.barh(x,y)
plt.title('Types of Comments')
plt.show()

# %%
print(len(language))
print(len(unlang))
# Out:
# 16
# 15
