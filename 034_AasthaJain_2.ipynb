# %% [markdown]
# <a href="https://colab.research.google.com/github/aastha621/Artificial-Intelligence/blob/main/034_AasthaJain_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **(Q1)Perform following on Dataset D1. Load dataset into appropriate data structure (data frame)**

# %% [markdown]
# ***(a)Detect missing values, and replace them with the mean.***

# %%
import pandas as pd
import io
import matplotlib.pyplot as plt
import numpy as np
from google.colab import files

uploaded=files.upload()

# made a function so that it can be reused
def func_nb():
   dframe = pd.read_csv(io.BytesIO(uploaded['popularity.csv'])) 
   return dframe

df=func_nb()

print(df)
# Out:
#      <input type="file" id="files-6d143bce-9063-4d9f-a4c9-2e0cb287eba5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6d143bce-9063-4d9f-a4c9-2e0cb287eba5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving popularity.csv to popularity (1).csv
#      Unnamed: 0  avg_shares  avg_comments  avg_expert  popularity_score
# 0            19       147.3          23.9        19.1              14.6
# 1            91        28.6           1.5        33.0               7.3
# 2           166        17.9          37.6        21.6               8.0
# 3           196        94.2           4.9         8.1               9.7
# 4            42       293.6          27.7         1.8              20.7
# ...

# %%
def fillMissing(df):
  sharesMean = df["avg_shares"].mean()
  commentsMean = df["avg_comments"].mean()
  expertMean = df["avg_expert"].mean()
  scoreMean = df["popularity_score"].mean()

    
  df["avg_shares"] = df["avg_shares"].fillna(sharesMean)
  df["avg_comments"] = df["avg_comments"].fillna(commentsMean)
  df["avg_expert"] = df["avg_expert"].fillna(expertMean)
  df["popularity_score"] = df["popularity_score"].fillna(scoreMean)

  return df


new_df=fillMissing(df)
#to check
print(new_df.loc[19,"avg_shares"]) 
print(new_df.loc[7,"avg_comments"])
# Out:
# 147.29145728643226
# 23.31938775510204

# %% [markdown]
# (b)Draw box-plots for each attribute to detect if there are any outliers. If there are outliers, ignore them for now.

# %%
import matplotlib.pyplot as plt
import numpy as np


print("boxplot for average shares")
plt.boxplot(df["avg_shares"])
plt.show()

print("boxplot for average comments")
plt.boxplot(df["avg_comments"])
plt.show()

print("boxplot for average expert")
plt.boxplot(df["avg_expert"])
plt.show()

print("boxplot for popularity score")
plt.boxplot(df["popularity_score"])
plt.show()
# Out:
# boxplot for average shares
# boxplot for average comments
# boxplot for average expert
# boxplot for popularity score

# %% [markdown]
# (c)Normalize all attributes within the range of 0 to 1.

# %%
df=func_nb()
df=fillMissing(df)

def normalise(df):
  column_maxes = df.max()
  df_max = column_maxes.max()
  normalized_df = df / df_max
  return normalized_df

ndf=normalise(df)
ndf.head()
# Out:
#    Unnamed: 0  avg_shares  avg_comments  avg_expert  popularity_score
# 0    0.064103    0.496964      0.080634    0.064440          0.049258
# 1    0.307018    0.096491      0.005061    0.111336          0.024629
# 2    0.560054    0.060391      0.126856    0.072874          0.026991
# 3    0.661269    0.317814      0.016532    0.027328          0.032726
# 4    0.141700    0.990553      0.093455    0.006073          0.069838

# %% [markdown]
# d)After performing the above pre-processing, draw box-plots for avg_shares and avg_comments in the same figure. Write your observations as comments.

# %%
import matplotlib.pyplot as plt
import numpy as np

df=func_nb() 
df=fillMissing(df) 
ndf=normalise(df)

# print(df)

print("boxplot for average shares")
plt.boxplot(ndf["avg_shares"])
plt.show()

print("boxplot for average comments")
plt.boxplot(ndf["avg_comments"])
plt.show()
# Out:
# boxplot for average shares
# boxplot for average comments

# %%
# in the box plot for average shares, (after normalisation)
# median lies between 0.6 and 0.4


# in the box plot for average comments, (after normalisation)
# median lies between 0.100 and 0.075

# %% [markdown]
# **(Q2)Perform following on Dataset D2. Load dataset into appropriate data structure (data frame)**

# %%
import pandas as pd

from google.colab import files

uploaded=files.upload()

df = pd.read_csv('a2.csv')
df.head()
# Out:
#      <input type="file" id="files-a847be81-2fb6-4018-8edf-963393f65fdb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a847be81-2fb6-4018-8edf-963393f65fdb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving a2.csv to a2.csv
#    PassengerId  Pclass      Name     Sex   Age Outcome
# 0          892       3     Kelly    male  34.5       Q
# 1          893       3    Wilkes  female  47.0       S
# 2          894       2     Myles    male  62.0       Q
# 3          895       3      Wirz    male  27.0       S
# 4          896       3  Hirvonen  female  22.0       S

# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('a2.csv')


sex_data = np.array(df["Sex"].value_counts())
chartlabels = ["male", "female"]
plt.pie(sex_data,labels=chartlabels,autopct='%1.1f%%')
plt.title('Sex ratio')
plt.axis('equal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

outcome_list = df['Outcome'].tolist()
# dictionary 
map = {} 

for i in my_list:
    map[i] = map.get(i, 0) + 1
print(map)
names = list(map.keys())
values = list(map.values())
plt.bar(range(len(map)), values, color='purple', tick_label=names)
plt.xlabel("OUTCOME")
plt.ylabel("No.of people")
plt.title("Outcome of train crash ")

plt.show()
# Out:
# {'Q': 13, 'S': 61, 'C': 26}

# %%
import pandas as pd
from sklearn import preprocessing
from google.colab import files

uploaded=files.upload()

df = pd.read_csv('a2.csv')
print(df)

  

label_encoder = preprocessing.LabelEncoder()
  
df['Sex']= label_encoder.fit_transform(df['Sex'])
  
df['Sex'].unique()

df.head()


# Label encoding is an important part of pre processing in Machine learning as it makes it easy for the machine to work with numeric data 
# instead of words/alphabetical characters
# Out:
#      <input type="file" id="files-152ff943-04df-4369-8e56-3a83c9ed7a3c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-152ff943-04df-4369-8e56-3a83c9ed7a3c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving a2.csv to a2 (1).csv
#     PassengerId  Pclass       Name     Sex   Age Outcome
# 0           892       3      Kelly    male  34.5       Q
# 1           893       3     Wilkes  female  47.0       S
# 2           894       2      Myles    male  62.0       Q
# 3           895       3       Wirz    male  27.0       S
# 4           896       3   Hirvonen  female  22.0       S
# ..          ...     ...        ...     ...   ...     ...
# 95          987       3    Tenglin    male  25.0       S
# 96          988       1  Cavendish  female  76.0       S
# ...

# %%
one_hot_encoded_data = pd.get_dummies(df, columns = ['Outcome'])
print(one_hot_encoded_data)

#one hot encoding allows the representation of categorical data
#to be more expressive. Many machine learning algorithms cannot work with categorical data directly.
# Out:
#     PassengerId  Pclass       Name  Sex   Age  Outcome_C  Outcome_Q  Outcome_S
# 0           892       3      Kelly    1  34.5          0          1          0
# 1           893       3     Wilkes    0  47.0          0          0          1
# 2           894       2      Myles    1  62.0          0          1          0
# 3           895       3       Wirz    1  27.0          0          0          1
# 4           896       3   Hirvonen    0  22.0          0          0          1
# ..          ...     ...        ...  ...   ...        ...        ...        ...
# 95          987       3    Tenglin    1  25.0          0          0          1
# 96          988       1  Cavendish    0  76.0          0          0          1
# 97          989       3    Makinen    1  29.0          0          0          1
# 98          990       3       Braf    0  20.0          0          0          1
# 99          991       3  Nancarrow    1  33.0          0          0          1
#
# [100 rows x 8 columns]

# %% [markdown]
# **(Q3)Perform the following on Dataset D3. Create your own copy of the google drive folder which contains the five images. Your program (written in google colab) should read from this folder that you have created**.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
from matplotlib.pyplot import imshow
import numpy as np
from PIL import Image


files=glob.glob('/content/drive/MyDrive/a2_img_data/*.jpg')

images = []
for file in files:
  images.append(np.array(Image.open(file)))

images=np.array(images, dtype=object)

resized_list= [] #an array of resized images

for image in images:
    resized_image=np.array(Image.fromarray(image).resize((100,100))) 
    resized_list.append(resized_image)

resized_list=np.array(resized_list)


for img in resized_list:
    imshow(Image.fromarray(img))

imshow(Image.fromarray(resized_list[0]))

# %%
from matplotlib.pyplot import imshow

imshow(Image.fromarray(resized_list[1]))

# %%
from matplotlib.pyplot import imshow

imshow(Image.fromarray(resized_list[2]))

# %%
imshow(Image.fromarray(resized_list[3]))

# %%
imshow(Image.fromarray(resized_list[4]))

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
  
img = cv2.imread(files[0])

color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
  
img = cv2.imread(files[1])

color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
img = cv2.imread(files[2])

color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
img = cv2.imread(files[3])

color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %%
  
img = cv2.imread(files[4])

color = ('b','g','r')
for i,col in enumerate(color):
    histr = cv2.calcHist([img],[i],None,[256],[0,256])
    plt.plot(histr,color = col)
    plt.xlim([0,256])
plt.show()

# %% [markdown]
# **(Q4)Perform the following on Dataset D4.**

# %% [markdown]
# (a)For each row of the ‘content’ attribute, find length of content, number of punctuations, number of stopwords, and number of times ‘@’ appears in the tweet text. Save these values into four new columns, name them as ‘length’, ‘punct’, ‘stopwords’, and ‘mentions’.

# %%
import pandas as pd
import io
from google.colab import files
uploaded = files.upload()

df = pd.read_csv(io.BytesIO(uploaded['text.csv']))
# Out:
#      <input type="file" id="files-50d57940-7325-4c3b-aadc-fa42e4501f18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-50d57940-7325-4c3b-aadc-fa42e4501f18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving text.csv to text (1).csv

# %%
df.head()
# Out:
#      tweet_id  ...                                            content
# 0  1956967341  ...  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666  ...  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696  ...                Funeral ceremony...gloomy friday...
# 3  1956967789  ...               wants to hang out with friends SOON!
# 4  1956968416  ...  @dannycastillo We want to trade with someone w...
#
# [5 rows x 4 columns]

# %%
df["Length"]= df["content"].str.len()
df.head()
# Out:
#      tweet_id  ... Length
# 0  1956967341  ...     92
# 1  1956967666  ...     60
# 2  1956967696  ...     35
# 3  1956967789  ...     36
# 4  1956968416  ...     86
#
# [5 rows x 5 columns]

# %%
chars = '[.?!,;:-]'

df['punct'] = df['content'].str.count(chars)

df.head()
# Out:
#      tweet_id   sentiment       author  ... punc_count  @_count  punct
# 0  1956967341       empty   xoshayzers  ...          0        1      0
# 1  1956967666     sadness    wannamama  ...          6        0      6
# 2  1956967696     sadness    coolfunky  ...          6        0      6
# 3  1956967789  enthusiasm  czareaquino  ...          1        0      1
# 4  1956968416     neutral    xkilljoyx  ...          2        1      2
#
# [5 rows x 8 columns]

# %%
df['mentions'] = df['content'].str.count('@')

df.head()
# Out:
#      tweet_id   sentiment       author  ... @_count  punct  mentions
# 0  1956967341       empty   xoshayzers  ...       1      0         1
# 1  1956967666     sadness    wannamama  ...       0      6         0
# 2  1956967696     sadness    coolfunky  ...       0      6         0
# 3  1956967789  enthusiasm  czareaquino  ...       0      1         0
# 4  1956968416     neutral    xkilljoyx  ...       1      2         1
#
# [5 rows x 9 columns]

# %% [markdown]
# (b)Draw correlation plot and find if any correlation exists between the ‘sentiment’ attribute with these four new columns (also known as features). You would be required to encode the ‘sentiment’ attribute. Interpret the correlation values as comments.

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

stop_words = set(stopwords.words('english'))
df['stopwords'] = df['content'].apply(lambda x: len(set(x.split()) & stop_words))

df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#      tweet_id   sentiment       author  ... punct  mentions  stopwords
# 0  1956967341       empty   xoshayzers  ...     0         1          6
# 1  1956967666     sadness    wannamama  ...     6         0          4
# 2  1956967696     sadness    coolfunky  ...     6         0          0
# 3  1956967789  enthusiasm  czareaquino  ...     1         0          3
# 4  1956968416     neutral    xkilljoyx  ...     2         1          6
#
# [5 rows x 10 columns]

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
df["Sentiment_Encode"] = lb_make.fit_transform(df["sentiment"])

df[["sentiment", "Sentiment_Encode"]].head()
# Out:
#     sentiment  Sentiment_Encode
# 0       empty                 2
# 1     sadness                10
# 2     sadness                10
# 3  enthusiasm                 3
# 4     neutral                 8

# %%
# creating a new dataframe for new columns (also known as features) with the encoded sentiment 
df1 = df.loc[:,["Sentiment_Encode","Length",'mentions','punct','stopwords']]
df1.head()
# Out:
#    Sentiment_Encode  Length  mentions  punct  stopwords
# 0                 2      92         1      0          6
# 1                10      60         0      6          4
# 2                10      35         0      6          0
# 3                 3      36         0      1          3
# 4                 8      86         1      2          6

# %%
correlations = df1.corr()
print(correlations)
# Out:
#                   Sentiment_Encode    Length  mentions     punct  stopwords
# Sentiment_Encode          1.000000  0.018013 -0.039919 -0.013817   0.066885
# Length                    0.018013  1.000000  0.139938  0.441100   0.751296
# mentions                 -0.039919  0.139938  1.000000  0.004779   0.023214
# punct                    -0.013817  0.441100  0.004779  1.000000   0.157207
# stopwords                 0.066885  0.751296  0.023214  0.157207   1.000000

# %%
 
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(correlations)
plt.show()

# %% [markdown]
# (c)Remove stopwords, and then tokenize words in each row of the ‘content’, count the number of words, and save into a new attribute ‘wordCount’. Use the NLTK library.

# %%
from nltk.corpus import stopwords
stop = stopwords.words('english')
df['remove_sw']=df['content'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# %%
df.head()
# Out:
#      tweet_id  ... wordCount
# 0  1956967341  ...        72
# 1  1956967666  ...        52
# 2  1956967696  ...        25
# 3  1956967789  ...        29
# 4  1956968416  ...        64
#
# [5 rows x 13 columns]

# %%
df['wordCount']=df['remove_sw'].apply(lambda x: len(str(x).split(' ')))
df.head(2)
# Out:
#      tweet_id  ... wordCount
# 0  1956967341  ...        72
# 1  1956967666  ...        52
#
# [2 rows x 13 columns]

# %% [markdown]
# (d)Draw separate word clouds for each of the following sentiment values: sadness, enthusiasm, and neutral. Write your observations as comments.

# %%
from wordcloud import WordCloud, STOPWORDS

sadness = df.loc[df['sentiment'] == 'sadness']

sad_tweets = ''.join(word for word in sadness['remove_sw'])
sadnesscloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(sad_tweets)
                   
plt.imshow(sadnesscloud)

#most used words are 'day', 'miss', 'sad'

# %%
enthu = df.loc[df['sentiment'] == 'enthusiasm']

enthu_tweets = ''.join(word for word in enthu['remove_sw'])
enthu_cloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(enthu_tweets)
                   
plt.imshow(enthu_cloud)

#most used words are 'want', 'good', 'great', 'hope' which indicate a happy and enthusiastic mood

# %%
neutral = df.loc[df['sentiment'] == 'neutral']

neutral_tweets = ''.join(word for word in neutral['remove_sw'])
neutral_cloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = stop_words,
                min_font_size = 10).generate(neutral_tweets)
                   
plt.imshow(neutral_cloud)

#most used words are 'get' , 'one', 'like', 'work'
